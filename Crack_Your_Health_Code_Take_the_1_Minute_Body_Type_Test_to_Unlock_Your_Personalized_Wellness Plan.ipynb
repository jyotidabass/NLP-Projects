# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotidabass/NLP-Projects/blob/main/Crack_Your_Health_Code_Take_the_1_Minute_Body_Type_Test_to_Unlock_Your_Personalized_Wellness%C2%A0Plan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class BodyConstitution:
    def __init__(self):
        self.characteristics = {
            "Body Frame": {"NEE": "Thin and Lean", "ME": "Medium", "SE": "Well Built"},
            "Type of Hair": {"NEE": "Dry and with Splits End", "ME": "Normal, Thin, More Hair Fall", "SE": "Greasy, Heavy"},
            "Color of Hair": {"NEE": "Pale Brown", "ME": "Red or Brown", "SE": "Jet Black"},
            "Skin": {"NEE": "Dry, Rough", "ME": "Soft, More Sweating, Acne", "SE": "Moist, Greasy"},
            "Complexion": {"NEE": "Dark, Blackish", "ME": "Pink to Red", "SE": "Glowing, White"},
            "Body Weight": {"NEE": "Low, Difficult to Put on weight", "ME": "Medium, Can Easily Lose or Gain Weight", "SE": "Overweight, Difficult to Lose Weight"},
            "Nails": {"NEE": "Blackish, Small, Brittle", "ME": "Reddish, Small", "SE": "Pinkish, Big, Smooth"},
            "Size and Color of the Teeth": {"NEE": "Very Big or Very Small, Irregular, Blackish", "ME": "Medium Sized, Yellowish", "SE": "Large, Shinning White"},
            "Pace of Performing Work": {"NEE": "Fast, Always in Hurry", "ME": "medium, Energetic", "SE": "Slow, Steady"},
            "Mental Activity": {"NEE": "Quick, Restless", "ME": "Smart Intellect, Aggressive", "SE": "Calm, Stable"},
            "Memory": {"NEE": "Short Term Bad", "ME": "Good Memory", "SE": "Long Term is Best"},
            "Grasping power": {"NEE": "Grasps Quickly but not Completely and Forgets Quickly", "ME": "Grasps Quickly but Completely and have Good Memory", "SE": "Grasps Late and Retains for Longer Time"},
            "Sleep Pattern": {"NEE": "Interrupted, Less", "ME": "Moderate", "SE": "Sleepy, Lazy"},
            "Intolerance to weather Conditions": {"NEE": "Aversion to Cold", "ME": "Aversion to Heat", "SE": "Aversion to Moist, Rainy and cool weather"},
            "Reactions Under Adverse Situation": {"NEE": "Anxiety, Worry, Irritability", "ME": "Anger, Aggression", "SE": "Calm, Reclusive, Sometimes Depressive"},
            "Mood": {"NEE": "Changes Quickly have Frequent Mood Swings", "ME": "Changes Slowly", "SE": "Stable Constant"},
            "Eating Habit": {"NEE": "Eats Quickly Without Chewing Properly", "ME": "Eats at a Moderate Speed", "SE": "Chews Food Properly"},
            "Hunger": {"NEE": "irregular, Any Time", "ME": "Sudden Hunger Pangs, Sharp Hunger", "SE": "Can Skip any Meal Easily"},
            "Body Temperature": {"NEE": "Less than Normal, Hands and Feets are Cold", "ME": "More than Normal, Face and Forehead Hot", "SE": "Normal, Hands and Feets Slightly Cold"},
            "Joints": {"NEE": "Weak, Noise on Movement", "ME": "Healthy with Optimal Strength", "SE": "Heavy Weight Bearing"},
            "Nature": {"NEE": "Timid, Jealous", "ME": "Egoistic, Fearless", "SE": "Forgiving, Greatful, Not Greedy"},
            "Body Energy": {"NEE": "Becomes Low in Evening, Fatigues After Less Work", "ME": "Moderate, Gets Tired After Medium Work", "SE": "Excellent Energy Throughout Day Not Easily Fatigued"},
            "Eyeball": {"NEE": "Unsteady, Fast Moving", "ME": "Moving Slowly", "SE": "Steady"},
            "Quality of Voice": {"NEE": "Rough with Broken Words", "ME": "Fast, Commanding", "SE": "Soft and Deep"},
            "Dreams": {"NEE": "Sky, Wind, Flying, Objects and Confusion", "ME": "Fire, Light, Bright Colors, Violence", "SE": "Water Pools, Gardens and Good Relationships"},
            "Social Relations": {"NEE": "Make Less Friends Prefers Solitude", "ME": "Good No. of Friends", "SE": "Love to Socialize. Relationships are Longer Lasting"},
            "Wealth": {"NEE": "Spends Without Thinking Much", "ME": "Saves but Spends on Valuable Things", "SE": "Prefers More Savings"},
            "Digestive System": {"NEE": "Tendency to Experience Gas and Bloating", "ME": "Tendency to Experience Heartburn and Acidity", "SE": "Tendency to Experience Constipation"},
            "Walking Pace": {"NEE": "Quick, Fast With long Steps", "ME": "Average, Steady", "SE": "Slow with Short Steps"},
            "Communication Skills": {"NEE": "Fast, Irrelevant Talk, Speech not Clear", "ME": "Good Speakers with Genuine Argumentative Skills", "SE": "Authoritative, Firm and Little Speech"}
        }

        self.disease_prone = {
            "NEE": ["Anxiety disorders", "Insomnia", "Digestive issues", "Skin problems"],
            "ME": ["Acid reflux", "High blood pressure", "Diabetes", "Obesity"],
            "SE": ["Respiratory issues", "Joint pain", "Depression", "Weight gain"]
        }

        self.nature = {
            "NEE": "You are a creative and imaginative person, but can be anxious and restless at times.",
            "ME": "You are a confident and ambitious person, but can be aggressive and competitive at times.",
            "SE": "You are a calm and stable person, but can be lazy and complacent at times."
        }

        self.lifestyle_recommendations = {
            "NEE": "You should prioritize relaxation and stress management techniques, such as meditation and yoga. You should also avoid spicy and oily foods.",
            "ME": "You should prioritize regular exercise and a balanced diet. You should also avoid excessive caffeine and sugar.",
            "SE": "You should prioritize regular physical activity and a healthy diet. You should also avoid excessive sleeping and laziness."
        }

    def calculate_body_constitution(self, user_answers):
        NEE_score = 0
        ME_score = 0
        SE_score = 0

        for characteristic, answer in user_answers.items():
            if self.characteristics[characteristic]["NEE"] == answer:
                NEE_score += 1
            elif self.characteristics[characteristic]["ME"] == answer:
                ME_score += 1
            elif self.characteristics[characteristic]["SE"] == answer:
                SE_score += 1

        scores = {
            "NEE": NEE_score,
            "ME": ME_score,
            "SE": SE_score
        }

        return scores

def main():
    body_constitution = BodyConstitution()

    print("Please answer the following questions with the corresponding characteristic:")
    user_answers = {}

    for characteristic, answers in body_constitution.characteristics.items():
        print(f"\n{characteristic}:")
        for energy, answer in answers.items():
            print(f"{energy}: {answer}")

        user_answer = input("Enter your answer (1 for NEE, 2 for ME, 3 for SE), or type the description: ")
        if user_answer == "1":
            user_answers[characteristic] = answers["NEE"]
        elif user_answer == "2":
            user_answers[characteristic] = answers["ME"]
        elif user_answer == "3":
            user_answers[characteristic] = answers["SE"]
        else:
            for energy, answer in answers.items():
                if user_answer.lower() == answer.lower():
                    user_answers[characteristic] = answer
                    break
            else:
                print("Invalid answer. Please try again.")
                return main()

    scores = body_constitution.calculate_body_constitution(user_answers)

    print("\nYour Body Constitution scores:")
    for energy, score in scores.items():
        print(f"{energy}: {score}")

    max_score = max(scores.values())
    constitutions = [energy for energy, score in scores.items() if score == max_score]

    if len(constitutions) == 1:
        print(f"\nYour dominant Body Constitution is: {constitutions[0]}")
        print(f"\nYou are prone to the following diseases: {body_constitution.disease_prone[constitutions[0]]}")
        print(f"\nYour nature is: {body_constitution.nature[constitutions[0]]}")
        print(f"\nLifestyle recommendations: {body_constitution.lifestyle_recommendations[constitutions[0]]}")
    else:
        print(f"\nYour dominant Body Constitutions are: {', '.join(constitutions)}")
        for constitution in constitutions:
            print(f"\nYou are prone to the following diseases: {body_constitution.disease_prone[constitution]}")
            print(f"\nYour nature is: {body_constitution.nature[constitution]}")
            print(f"\nLifestyle recommendations: {body_constitution.lifestyle_recommendations[constitution]}")

if __name__ == "__main__":
    main()
# Out:
# Please answer the following questions with the corresponding characteristic:
#
# Body Frame:
# NEE: Thin and Lean
# ME: Medium
# SE: Well Built
# Enter your answer (1 for NEE, 2 for ME, 3 for SE), or type the description: 1
#
# Type of Hair:
# NEE: Dry and with Splits End
# ME: Normal, Thin, More Hair Fall
# SE: Greasy, Heavy
# Enter your answer (1 for NEE, 2 for ME, 3 for SE), or type the description: 1
#
# Color of Hair:
# NEE: Pale Brown
# ME: Red or Brown
# SE: Jet Black
# Enter your answer (1 for NEE, 2 for ME, 3 for SE), or type the description: 1
#
# Skin:
# NEE: Dry, Rough
# ME: Soft, More Sweating, Acne
# SE: Moist, Greasy
# Enter your answer (1 for NEE, 2 for ME, 3 for SE), or type the description: 1
#
# Complexion:
# NEE: Dark, Blackish
# ME: Pink to Red
# SE: Glowing, White
# Enter your answer (1 for NEE, 2 for ME, 3 for SE), or type the description: 3
#
# Body Weight:
# NEE: Low, Difficult to Put on weight
# ME: Medium, Can Easily Lose or Gain Weight
# ...
